# %%
# Imports

import os

import ee
import eeUtil

from .defs.compute_landscape_indicators import (
    compute_all_landscape_indicators,
    visualize,
)

# Initialize Earth Engine
PROJECT = os.getenv("GEE_PROJECT")
GEE_JSON = os.getenv("GEE_JSON")

assert PROJECT is not None, "Please set GEE_PROJECT environment variable"
assert (
    GEE_JSON is not None
), "Please set GEE_JSON environment variable with service account credentials"

eeUtil.init()

# %%
PROJECTION = "EPSG:4326"
SRC_FOLDER = "projects/ee-fgassert/assets/landscape_indicators_source"
WORKING_FOLDER = f"projects/{PROJECT}/assets/landscape_indicators_20230821"
WORLD_GEOM = ee.Geometry.Polygon(
    coords=[[[-180, -85], [-180, 85], [180, 85], [180, -85], [-180, -85]]],
    proj=PROJECTION,
    geodesic=False,
)
EXPORT_BUCKET = os.getenv("GEE_BUCKET")
EXPORT_PREFIX = "landscape_indicators_20230821"

TARGET_YEAR = 2022

ANALYSIS_SCALE = 100
KERNEL_SCALE = 1000
GAUL_FC = "FAO/GAUL/2015/level0"

RADII = [500, 5000, 10000, 25000, 50000]
COUNTRY_ANALYSIS_LAYERS = [
    "cropland_deforest_by_human_lu",
    "cropland_tree_loss_by_human_lu",
    "cropland_deforest_carbon_by_human_lu",
    "cropland_natural_crop_net_conversion_by_human_lu",
    "nonnat_deforest_by_human_lu",
    "nonnat_tree_loss_by_human_lu",
    "nonnat_deforest_carbon_by_human_lu",
    "nonnat_natural_crop_net_conversion_by_human_lu",
]

# %%
def cache_radii_layers():
    for r in RADII:
        compute_all_landscape_indicators(cache=True, kernel_radius=r)


def stack_layers_to_bands(layers):
    """Stacks a list of layers into a single image"""
    im = ee.Image(1).rename("const")
    for k, v in layers.items():
        im = im.addBands(v.rename(k))
    return im


def compute_country_stats_by_radii():
    gaul = ee.FeatureCollection(GAUL_FC)
    layers = {}
    for r in RADII:
        for k in COUNTRY_ANALYSIS_LAYERS:
            rad_km = int(r / 1000)
            key = f"{k}_{rad_km}km_{KERNEL_SCALE}m"
            layers[key] = ee.Image(f"{WORKING_FOLDER}/{key}")

    im = stack_layers_to_bands(layers)
    im = im.multiply(ee.Image.pixelArea()).divide(1e6)  # convert to km2
    table = im.reduceRegions(gaul, "sum", KERNEL_SCALE).select([".*"], None, False)
    asset_id = f"{EXPORT_PREFIX}/sluc_kernel_country_stats_{KERNEL_SCALE}m"
    desc = eeUtil.eeutil._getExportDescription(asset_id)
    if desc in [t["description"] for t in eeUtil.getTasks(True)]:
        print(f"{asset_id} in progress")
    else:
        ee.batch.Export.table.toCloudStorage(table, desc, EXPORT_BUCKET, asset_id).start()


def and_assume_disjoint(*args):
    im = ee.Image([*args]).reduce("sum")
    return im.subtract(im.mask()).max(0)


def get_dluc_layers():
    mask = ee.Image(f"{WORKING_FOLDER}/available_area_mask_{ANALYSIS_SCALE}m")
    cropland = ee.Image(f"{WORKING_FOLDER}/cropland_2019_{ANALYSIS_SCALE}m").updateMask(mask)
    nonnat = ee.Image(f"{WORKING_FOLDER}/nonnatural_excl_builtwater_{ANALYSIS_SCALE}m").updateMask(
        mask
    )
    treeloss = (
        ee.Image(f"{WORKING_FOLDER}/tree_loss_to{TARGET_YEAR}_{ANALYSIS_SCALE}m")
        .divide(20)
        .updateMask(mask)
    )
    deforest = ee.Image(f"{WORKING_FOLDER}/deforest_{ANALYSIS_SCALE}m").divide(20).updateMask(mask)
    deforest_carbon = (
        ee.Image(f"{WORKING_FOLDER}/deforest_carbon_{ANALYSIS_SCALE}m").divide(20).updateMask(mask)
    )

    nat_treeloss = treeloss.multiply(nonnat.subtract(1).multiply(-1))
    return {
        "cropland": cropland,
        "nonnat": nonnat,
        "deforest": deforest,
        "deforest_carbon": deforest_carbon,
        "treeloss": treeloss,
        "nat_treeloss": nat_treeloss,
        "dluc_cropland_treeloss": cropland.multiply(treeloss),
        "dluc_nonnat_treeloss": nonnat.multiply(treeloss),
        "dluc_cropland_nattreeloss": cropland.multiply(nat_treeloss),
        "dluc_nonnat_nattreeloss": nonnat.multiply(nat_treeloss),
        "dluc_cropland_deforest": cropland.multiply(deforest),
        "dluc_nonnat_deforest": nonnat.multiply(deforest),
        "dluc_cropland_deforest_carbon": cropland.multiply(deforest_carbon),
        "dluc_nonnat_deforest_carbon": nonnat.multiply(deforest_carbon),
    }


def compute_country_stats_dluc():
    """Compute the DLUC indicator for each country"""
    gaul = ee.FeatureCollection(GAUL_FC)
    dluc_layers = get_dluc_layers()

    im = stack_layers_to_bands(dluc_layers)
    im = im.multiply(ee.Image.pixelArea()).divide(1e6)  # convert to km2
    table = im.reduceRegions(gaul, "sum", ANALYSIS_SCALE, tileScale=4).select([".*"], None, False)
    asset_id = f"{EXPORT_PREFIX}/country_stats_{ANALYSIS_SCALE}m"
    desc = eeUtil.eeutil._getExportDescription(asset_id)
    if desc in [t["description"] for t in eeUtil.getTasks(True)]:
        print(f"{asset_id} in progress")
    else:
        ee.batch.Export.table.toCloudStorage(table, desc, EXPORT_BUCKET, asset_id).start()

# %%
visualize(get_dluc_layers())
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab1e83c5ab452e8235ed7813f67d6798 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab1e83c5ab452e8235ed7813f67d6798&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab1e83c5ab452e8235ed7813f67d6798 = L.map(
#                 &quot;map_ab1e83c5ab452e8235ed7813f67d6798&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3e57e9b1c714f42ce164d90d8c54dc2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab1e83c5ab452e8235ed7813f67d6798);
#
#
#             var tile_layer_b2101d009e980c8a941b44811bb978d9 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab1e83c5ab452e8235ed7813f67d6798);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_ab1e83c5ab452e8235ed7813f67d6798);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_ab1e83c5ab452e8235ed7813f67d6798
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_723c780d155c4c9b2fe5d7ab87e72710 = new L.Control.Draw(
#                 options
#             ).addTo( map_ab1e83c5ab452e8235ed7813f67d6798 );
#             map_ab1e83c5ab452e8235ed7813f67d6798.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_ab1e83c5ab452e8235ed7813f67d6798.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_ab1e83c5ab452e8235ed7813f67d6798.setView(e.geocode.center, 11);
#             }).addTo(map_ab1e83c5ab452e8235ed7813f67d6798);
#
#
#
#             map_ab1e83c5ab452e8235ed7813f67d6798.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_efed1bc8f0ddbf582e7066e70f65d6e3 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab1e83c5ab452e8235ed7813f67d6798);

# %%
# run country-level analysis
# cache_radii_layers()

# compute_country_stats_by_radii()
compute_country_stats_dluc()

# %%
[f"{t['state']} {t['description']}" for t in eeUtil.getTasks()]
# [ee.data.cancelTask(t['id']) for t in eeUtil.getTasks(True)]
# Out:
# ['RUNNING landscape_indicators_20230821:country_stats_100m',
#  'RUNNING landscape_indicators_20230821:sluc_kernel_country_stats_1000m',
#  'CANCELLED landscape_indicators_20230821:country_stats_100m',
#  'CANCELLED landscape_indicators_20230821:sluc_kernel_country_stats_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_0km_1000m',
#  'RUNNING landscape_indicators_20230821:nonnat_deforest',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest',
#  'RUNNING landscape_indicators_20230821:nonnat_nattreeloss',
#  'COMPLETED landscape_indicators_20230821:cropland_nattreeloss',
#  'COMPLETED landscape_indicators_20230821:nonnat_treeloss',
#  'COMPLETED landscape_indicators_20230821:cropland_treeloss',
#  'COMPLETED landscape_indicators_20230821:nat_treeloss',
#  'COMPLETED landscape_indicators_20230821:treeloss',
#  'COMPLETED landscape_indicators_20230821:deforest',
#  'COMPLETED landscape_indicators_20230821:nonnat',
#  'COMPLETED landscape_indicators_20230821:cropland',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_50km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_25km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_0km_1000m',
#  'FAILED landscape_indicators_20230821:cropland_deforest_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest',
#  'CANCELLED landscape_indicators_20230821:nonnat_treeloss',
#  'CANCELLED landscape_indicators_20230821:cropland_treeloss',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_5km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_nattreeloss',
#  'CANCELLED landscape_indicators_20230821:cropland_nattreeloss',
#  'CANCELLED landscape_indicators_20230821:nat_treeloss',
#  'CANCELLED landscape_indicators_20230821:treeloss',
#  'CANCELLED landscape_indicators_20230821:deforest',
#  'CANCELLED landscape_indicators_20230821:nonnat',
#  'CANCELLED landscape_indicators_20230821:cropland',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_0km_1000m',
#  'CANCELLED landscape_indicators_20230821:nat_treeloss',
#  'CANCELLED landscape_indicators_20230821:nonnat_nattreeloss',
#  'CANCELLED landscape_indicators_20230821:cropland_nattreeloss',
#  'CANCELLED landscape_indicators_20230821:treeloss',
#  'CANCELLED landscape_indicators_20230821:deforest',
#  'CANCELLED landscape_indicators_20230821:nonnat',
#  'CANCELLED landscape_indicators_20230821:cropland',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_50km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_deforest_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:cropland_deforest_by_human_lu_25km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_10km_1000m',
#  'CANCELLED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_10km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_5km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest_by_human_lu_0km_1000m',
#  'COMPLETED landscape_indicators_20230821:nonnat_deforest',
#  'COMPLETED landscape_indicators_20230821:cropland_deforest',
#  'COMPLETED landscape_indicators_20230821:nonnat_treeloss',
#  'COMPLETED landscape_indicators_20230821:cropland_treeloss',
#  'COMPLETED ssert:assets:landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'COMPLETED ert:assets:landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'COMPLETED -fgassert:assets:landscape_indicators_20230821:nonnat_natural_crop_conversion_by_human_lu_25km_1000m',
#  'COMPLETED gassert:assets:landscape_indicators_20230821:cropland_natural_crop_conversion_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_tree_loss_by_human_lu_25km_1000m',
#  'COMPLETED jects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_25km_1000m',
#  'COMPLETED cts:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_by_human_lu_25km_1000m',
#  'COMPLETED :ee-fgassert:assets:landscape_indicators_20230821:natural_crop_net_conversion_by_human_lu_25km_1000m',
#  'COMPLETED ects:ee-fgassert:assets:landscape_indicators_20230821:natural_crop_conversion_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_by_human_lu_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnatural_kernel_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_reduction_kernel_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_expansion_kernel_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_kernel_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_kernel_25km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_kernel_25km_1000m',
#  'COMPLETED ssert:assets:landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED ert:assets:landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED -fgassert:assets:landscape_indicators_20230821:nonnat_natural_crop_conversion_by_human_lu_10km_1000m',
#  'COMPLETED gassert:assets:landscape_indicators_20230821:cropland_natural_crop_conversion_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED jects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_10km_1000m',
#  'COMPLETED cts:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_by_human_lu_10km_1000m',
#  'COMPLETED :ee-fgassert:assets:landscape_indicators_20230821:natural_crop_net_conversion_by_human_lu_10km_1000m',
#  'COMPLETED ects:ee-fgassert:assets:landscape_indicators_20230821:natural_crop_conversion_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_by_human_lu_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnatural_kernel_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_reduction_kernel_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_expansion_kernel_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_kernel_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_kernel_10km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_kernel_10km_1000m',
#  'COMPLETED assert:assets:landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED sert:assets:landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED e-fgassert:assets:landscape_indicators_20230821:nonnat_natural_crop_conversion_by_human_lu_5km_1000m',
#  'COMPLETED fgassert:assets:landscape_indicators_20230821:cropland_natural_crop_conversion_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED ojects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED ects:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_by_human_lu_5km_1000m',
#  'COMPLETED s:ee-fgassert:assets:landscape_indicators_20230821:natural_crop_net_conversion_by_human_lu_5km_1000m',
#  'COMPLETED jects:ee-fgassert:assets:landscape_indicators_20230821:natural_crop_conversion_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_by_human_lu_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnatural_kernel_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_reduction_kernel_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_expansion_kernel_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_kernel_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_kernel_5km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_kernel_5km_1000m',
#  'COMPLETED assert:assets:landscape_indicators_20230821:nonnat_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED sert:assets:landscape_indicators_20230821:cropland_natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED e-fgassert:assets:landscape_indicators_20230821:nonnat_natural_crop_conversion_by_human_lu_0km_1000m',
#  'COMPLETED fgassert:assets:landscape_indicators_20230821:cropland_natural_crop_conversion_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED ojects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED ects:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnat_deforest_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:cropland_deforest_by_human_lu_0km_1000m',
#  'COMPLETED s:ee-fgassert:assets:landscape_indicators_20230821:natural_crop_net_conversion_by_human_lu_0km_1000m',
#  'COMPLETED jects:ee-fgassert:assets:landscape_indicators_20230821:natural_crop_conversion_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_by_human_lu_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:nonnatural_kernel_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_reduction_kernel_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:natcrop_expansion_kernel_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_carbon_kernel_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:deforest_kernel_0km_1000m',
#  'COMPLETED projects:ee-fgassert:assets:landscape_indicators_20230821:tree_loss_kernel_0km_1000m']
